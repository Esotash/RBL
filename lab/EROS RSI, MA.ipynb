# %%
pip install yfinance

# %%
import yfinance as yahooFinance

# in order to specify start date and
# end date we need datetime package
import datetime

# startDate , as per our convenience we can modify
startDate = datetime.datetime(2010, 1, 1)

# endDate , as per our convenience we can modify
endDate = datetime.datetime(2020, 1, 1)
GetFacebookInformation = yahooFinance.Ticker("^NSEI")

# pass the parameters as the taken dates for start and end
print(GetFacebookInformation.history(start=startDate,end=endDate))
# Out:
#                                    Open          High           Low  \
# Date
# 2010-01-04 00:00:00+05:30   5200.899902   5238.450195   5167.100098
# 2010-01-05 00:00:00+05:30   5277.149902   5288.350098   5242.399902
# 2010-01-06 00:00:00+05:30   5278.149902   5310.850098   5260.049805
# 2010-01-07 00:00:00+05:30   5281.799805   5302.549805   5244.750000
# 2010-01-08 00:00:00+05:30   5264.250000   5276.750000   5234.700195
# ...                                 ...           ...           ...
# 2019-12-24 00:00:00+05:30  12269.250000  12283.700195  12202.099609
# 2019-12-26 00:00:00+05:30  12211.849609  12221.549805  12118.849609
# 2019-12-27 00:00:00+05:30  12172.900391  12258.450195  12157.900391
# 2019-12-30 00:00:00+05:30  12274.900391  12286.450195  12213.799805
# 2019-12-31 00:00:00+05:30  12247.099609  12247.099609  12151.799805
#
#                                   Close  Volume  Dividends  Stock Splits
# Date
# ...

# %%
import yfinance as yahooFinance

# in order to specify start date and
# end date we need datetime package
import datetime

# startDate , as per our convenience we can modify
startDate = datetime.datetime(2010, 1, 1)

# endDate , as per our convenience we can modify
endDate = datetime.datetime(2020, 1, 1)
GetFacebookInformation = yahooFinance.Ticker("^NSEI")

# pass the parameters as the taken dates for start and end
print(GetFacebookInformation.history(start=startDate,end=endDate))
# Out:
#                                    Open          High           Low  \
# Date
# 2010-01-04 00:00:00+05:30   5200.899902   5238.450195   5167.100098
# 2010-01-05 00:00:00+05:30   5277.149902   5288.350098   5242.399902
# 2010-01-06 00:00:00+05:30   5278.149902   5310.850098   5260.049805
# 2010-01-07 00:00:00+05:30   5281.799805   5302.549805   5244.750000
# 2010-01-08 00:00:00+05:30   5264.250000   5276.750000   5234.700195
# ...                                 ...           ...           ...
# 2019-12-24 00:00:00+05:30  12269.250000  12283.700195  12202.099609
# 2019-12-26 00:00:00+05:30  12211.849609  12221.549805  12118.849609
# 2019-12-27 00:00:00+05:30  12172.900391  12258.450195  12157.900391
# 2019-12-30 00:00:00+05:30  12274.900391  12286.450195  12213.799805
# 2019-12-31 00:00:00+05:30  12247.099609  12247.099609  12151.799805
#
#                                   Close  Volume  Dividends  Stock Splits
# Date
# ...

# %%
# prompt: i want to save the rsi value in one csv file

# Assuming 'nifty_data' DataFrame already contains the RSI column

# Extract only the RSI values and the Date column
rsi_data = nifty_data[['Date', 'RSI']]

# Save RSI data to a new CSV file
rsi_data.to_csv('/content/NSE501.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-7b9a14eb8a65> in <cell line: 2>()
#       1 # Save to CSV if needed
# ----> 2 nifty_data.to_csv('nifty50_ohlc_data.csv')
#
# NameError: name 'nifty_data' is not defined

# %%
import yfinance as yahooFinance
import datetime

# startDate , as per our convenience we can modify
startDate = datetime.datetime(2010, 1, 1)

# endDate , as per our convenience we can modify
endDate = datetime.datetime(2020, 1, 1)
GetFacebookInformation = yahooFinance.Ticker("^NSEI")

# pass the parameters as the taken dates for start and end
# This line is crucial: it assigns the retrieved data to nifty_data
nifty_data = GetFacebookInformation.history(start=startDate,end=endDate)
print(nifty_data)

# Save to CSV if needed
nifty_data.to_csv('OHLC.Csv')
# Out:
#                                    Open          High           Low  \
# Date
# 2010-01-04 00:00:00+05:30   5200.899902   5238.450195   5167.100098
# 2010-01-05 00:00:00+05:30   5277.149902   5288.350098   5242.399902
# 2010-01-06 00:00:00+05:30   5278.149902   5310.850098   5260.049805
# 2010-01-07 00:00:00+05:30   5281.799805   5302.549805   5244.750000
# 2010-01-08 00:00:00+05:30   5264.250000   5276.750000   5234.700195
# ...                                 ...           ...           ...
# 2019-12-24 00:00:00+05:30  12269.250000  12283.700195  12202.099609
# 2019-12-26 00:00:00+05:30  12211.849609  12221.549805  12118.849609
# 2019-12-27 00:00:00+05:30  12172.900391  12258.450195  12157.900391
# 2019-12-30 00:00:00+05:30  12274.900391  12286.450195  12213.799805
# 2019-12-31 00:00:00+05:30  12247.099609  12247.099609  12151.799805
#
#                                   Close  Volume  Dividends  Stock Splits
# Date
# ...

# %%
# prompt: remove Dividends  Stock Splits
# form the excl

# Assuming 'nifty_data' contains your DataFrame
nifty_data = nifty_data[['Open', 'High', 'Low', 'Close', 'Volume']]

# Save to CSV if needed
nifty_data.to_csv('NSE50.csv')

# %% [markdown]
# # RSI FROM HERE

# %%
import pandas as pd
import numpy as np

# Function to calculate RSI
def calculate_rsi(data, window=14):
    delta = data['Close'].diff()  # Calculate the difference between consecutive close prices
    gain = np.where(delta > 0, delta, 0)  # Take only the positive differences (gains)
    loss = np.where(delta < 0, -delta, 0)  # Take only the negative differences (losses)

    avg_gain = pd.Series(gain).rolling(window=window, min_periods=1).mean()  # Rolling average of gains
    avg_loss = pd.Series(loss).rolling(window=window, min_periods=1).mean()  # Rolling average of losses

    rs = avg_gain / avg_loss  # Relative Strength (RS)
    rsi = 100 - (100 / (1 + rs))  # RSI formula

    data['RSI'] = rsi  # Add RSI to the dataframe
    return data

# Apply RSI to the Nifty 50 OHLC data
nifty_data = pd.read_csv('/content/NSE50.csv')  # Load data (assumed already saved)
nifty_data = calculate_rsi(nifty_data)

# Display the data with RSI
print(nifty_data[['Date','Open','High','Low','Close','RSI']].tail())

# Save the DataFrame with RSI data to a new CSV file
data.to_csv('NSE502.csv', index=False)
# Out:
#                            Date          Open          High           Low  \
# 2438  2019-12-24 00:00:00+05:30  12269.250000  12283.700195  12202.099609
# 2439  2019-12-26 00:00:00+05:30  12211.849609  12221.549805  12118.849609
# 2440  2019-12-27 00:00:00+05:30  12172.900391  12258.450195  12157.900391
# 2441  2019-12-30 00:00:00+05:30  12274.900391  12286.450195  12213.799805
# 2442  2019-12-31 00:00:00+05:30  12247.099609  12247.099609  12151.799805
#
#              Close        RSI
# 2438  12214.549805  61.330392
# 2439  12126.549805  56.599703
# 2440  12245.799805  69.264568
# 2441  12255.849609  69.045744
# 2442  12168.450195  68.496687

# %%
# prompt: i want to save the above data in the csv file

# Assuming 'nifty_data' DataFrame already contains the RSI column and other OHLC data

# Save the DataFrame with RSI and OHLC data to a new CSV file
nifty_data.to_csv('NSE502.csv', index=False)

# %%
import matplotlib.pyplot as plt

# Plot the Close price and RSI
plt.figure(figsize=(14, 8))

# Plot the closing price
plt.subplot(2, 1, 1)
plt.plot(nifty_data['Date'], nifty_data['Close'], label='Close Price')
plt.title('Nifty 50 Close Price')
plt.legend()

# Plot the RSI
plt.subplot(2, 1, 2)
plt.plot(nifty_data['Date'], nifty_data['RSI'], label='RSI', color='orange')
plt.axhline(70, color='red', linestyle='--')  # Overbought level
plt.axhline(30, color='green', linestyle='--')  # Oversold level
plt.title('Nifty 50 RSI')
plt.legend()

plt.tight_layout()
plt.show()

# %%
pip install pandas

# %%
import pandas as pd

# Load your data
data = pd.read_csv('/content/NSE50.csv')

# Display the first few rows
print(data.head())
# Out:
#                         Date         Open         High          Low  \
# 0  2010-01-04 00:00:00+05:30  5200.899902  5238.450195  5167.100098
# 1  2010-01-05 00:00:00+05:30  5277.149902  5288.350098  5242.399902
# 2  2010-01-06 00:00:00+05:30  5278.149902  5310.850098  5260.049805
# 3  2010-01-07 00:00:00+05:30  5281.799805  5302.549805  5244.750000
# 4  2010-01-08 00:00:00+05:30  5264.250000  5276.750000  5234.700195
#
#          Close  Volume
# 0  5232.200195       0
# 1  5277.899902       0
# 2  5281.799805       0
# 3  5263.100098       0
# 4  5244.750000       0

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load your data
data = pd.read_csv('/content/NSE50.csv')

# Ensure the 'Date' column is in datetime format
data['Date'] = pd.to_datetime(data['Date'])

# Calculate Simple Moving Average (SMA)
def calculate_sma(data, window):
    return data['Close'].rolling(window=window).mean()

# Calculate Exponential Moving Average (EMA)
def calculate_ema(data, window):
    return data['Close'].ewm(span=window, adjust=False).mean()

# Define window sizes for SMA and EMA
windows = [20, 50, 100, 150, 200]

# Calculate SMA and EMA for each window size and add to DataFrame
for window in windows:
    data[f'SMA_{window}'] = calculate_sma(data, window)
    data[f'EMA_{window}'] = calculate_ema(data, window)

# Display the updated DataFrame with SMAs and EMAs
print(data[['Date', 'Close'] + [f'SMA_{window}' for window in windows] + [f'EMA_{window}' for window in windows]].head())

# Optional: Plotting
plt.figure(figsize=(14, 7))
plt.plot(data['Date'], data['Close'], label='Close Price', color='blue')

# Plot SMA and EMA
for window in windows:
    plt.plot(data['Date'], data[f'SMA_{window}'], label=f'{window}-Day SMA', linestyle='--')
    plt.plot(data['Date'], data[f'EMA_{window}'], label=f'{window}-Day EMA', linestyle=':')

# Save the DataFrame with SMA and EMA data to a new CSV file
data.to_csv('NSE501.csv', index=False)

plt.title('Nifty 50 Close Price with Moving Averages')
plt.xlabel('Date')
plt.ylabel('Price')
plt.xticks(rotation=45)
plt.legend()
plt.show()
# Out:
#                        Date        Close  SMA_20  SMA_50  SMA_100  SMA_150  \
# 0 2010-01-04 00:00:00+05:30  5232.200195     NaN     NaN      NaN      NaN
# 1 2010-01-05 00:00:00+05:30  5277.899902     NaN     NaN      NaN      NaN
# 2 2010-01-06 00:00:00+05:30  5281.799805     NaN     NaN      NaN      NaN
# 3 2010-01-07 00:00:00+05:30  5263.100098     NaN     NaN      NaN      NaN
# 4 2010-01-08 00:00:00+05:30  5244.750000     NaN     NaN      NaN      NaN
#
#    SMA_200       EMA_20       EMA_50      EMA_100      EMA_150      EMA_200
# 0      NaN  5232.200195  5232.200195  5232.200195  5232.200195  5232.200195
# 1      NaN  5236.552548  5233.992341  5233.105140  5232.805489  5232.654919
# 2      NaN  5240.861811  5235.867143  5234.069391  5233.454421  5233.143923
# 3      NaN  5242.979743  5236.935102  5234.644256  5233.847079  5233.441994
# 4      NaN  5243.148339  5237.241569  5234.844370  5233.991488  5233.554511

# %%
# prompt: make an new csv named NSE501 With all the ema and sma data

# Assuming 'data' DataFrame already contains SMA and EMA columns as calculated in the previous code

# Save the DataFrame with SMA and EMA data to a new CSV file
data.to_csv('NSE501.csv', index=False)

# %% [markdown]
# # LSTM

# %%
pip install tensorflow pandas numpy matplotlib scikit-learn

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler

# Load your data
data = pd.read_csv('/content/NSE50.csv')

# Ensure the 'Date' column is in datetime format
data['Date'] = pd.to_datetime(data['Date'])

# Calculate RSI (e.g., 14 days)
def calculate_rsi(data, period=14):
    delta = data['Close'].diff()
    gain = (delta.where(delta > 0, 0)).rolling(window=period).mean()
    loss = (-delta.where(delta < 0, 0)).rolling(window=period).mean()
    rs = gain / loss
    return 100 - (100 / (1 + rs))

data['RSI'] = calculate_rsi(data)

# Define window sizes for SMA and EMA
windows = [20, 50, 100, 150, 200]

# Calculate SMA and EMA
for window in windows:
    data[f'SMA_{window}'] = data['Close'].rolling(window=window).mean()
    data[f'EMA_{window}'] = data['Close'].ewm(span=window, adjust=False).mean()

# Drop rows with NaN values
data = data.dropna()

# Select features and target
features = data[['RSI'] + [f'SMA_{window}' for window in windows] + [f'EMA_{window}' for window in windows]]
target = data['Close']

# Normalize the features
scaler = MinMaxScaler()
features_scaled = scaler.fit_transform(features)

# Convert target to numpy array
target_scaled = target.values

# %%
# Define the time step
time_step = 60  # Number of previous days to consider for prediction

# Create the datasets
X, y = [], []
for i in range(time_step, len(features_scaled)):
    X.append(features_scaled[i-time_step:i])
    y.append(target_scaled[i])

X, y = np.array(X), np.array(y)

# Split into training and testing sets (80% training, 20% testing)
train_size = int(len(X) * 0.8)
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout

# Define the LSTM model
model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(Dropout(0.2))
model.add(LSTM(50, return_sequences=False))
model.add(Dropout(0.2))
model.add(Dense(25))
model.add(Dense(1))  # Output layer

# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error')

# Train the model
model.fit(X_train, y_train, batch_size=32, epochs=100)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - loss: 55233264.0000
# Epoch 2/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 3s 52ms/step - loss: 54261676.0000
# Epoch 3/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 5s 52ms/step - loss: 54806620.0000
# Epoch 4/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 5s 52ms/step - loss: 53908340.0000
# Epoch 5/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 7s 80ms/step - loss: 51708616.0000
# Epoch 6/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 52ms/step - loss: 51219228.0000
# Epoch 7/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 5s 51ms/step - loss: 49490452.0000
# Epoch 8/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 6s 62ms/step - loss: 47854732.0000
# Epoch 9/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - loss: 45706956.0000
# ...

# %%
# Make predictions
predictions = model.predict(X_test)

# Inverse transform the predictions and actual values
predictions = scaler.inverse_transform(predictions)
y_test_inverse = scaler.inverse_transform(y_test.reshape(-1, 1))

# Plotting the results
import matplotlib.pyplot as plt

plt.figure(figsize=(14, 7))
plt.plot(data['Date'].iloc[train_size + time_step:], y_test_inverse, label='Actual Price', color='blue')
plt.plot(data['Date'].iloc[train_size + time_step:], predictions, label='Predicted Price', color='orange')
plt.title('Nifty 50 Price Prediction with LSTM')
plt.xlabel('Date')
plt.ylabel('Price')
plt.xticks(rotation=45)
plt.legend()
plt.show()
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-37-c9446f882899> in <cell line: 5>()
#       3
#       4 # Inverse transform the predictions and actual values
# ----> 5 predictions = scaler.inverse_transform(predictions)
#       6 y_test_inverse = scaler.inverse_transform(y_test.reshape(-1, 1))
#       7
#
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_data.py in inverse_transform(self, X)
#     572         )
#     573
# --> 574         X -= self.min_
#     575         X /= self.scale_
#     576         return X
#
# ValueError: non-broadcastable output operand with shape (437,1) doesn't match the broadcast shape (437,11)

# %%
from sklearn.preprocessing import MinMaxScaler

# Initialize scalers
feature_scaler = MinMaxScaler()
target_scaler = MinMaxScaler()

# Normalize features
features_scaled = feature_scaler.fit_transform(features)

# Reshape target for scaling
target_scaled = target.values.reshape(-1, 1)
target_scaled = target_scaler.fit_transform(target_scaled)

# %%
# Make predictions
predictions = model.predict(X_test)

# Inverse transform the predictions and actual values using target_scaler
predictions = target_scaler.inverse_transform(predictions)
y_test_inverse = target_scaler.inverse_transform(y_test.reshape(-1, 1))
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout

# Load your data
data = pd.read_csv('/content/NSE500.csv')
data['Date'] = pd.to_datetime(data['Date'])

# Calculate RSI and moving averages...
# (Include your RSI and moving average calculations here)

# Drop rows with NaN values
data = data.dropna()

# Select features and target
features = data[['RSI'] + [f'SMA_{window}' for window in windows] + [f'EMA_{window}' for window in windows]]
target = data['Close']

# Initialize scalers
feature_scaler = MinMaxScaler()
target_scaler = MinMaxScaler()

# Normalize features
features_scaled = feature_scaler.fit_transform(features)

# Reshape target for scaling
target_scaled = target.values.reshape(-1, 1)
target_scaled = target_scaler.fit_transform(target_scaled)

# Create the datasets
X, y = [], []
for i in range(time_step, len(features_scaled)):
    X.append(features_scaled[i-time_step:i])
    y.append(target_scaled[i])

X, y = np.array(X), np.array(y)

# Split into training and testing sets
train_size = int(len(X) * 0.8)
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

# Build the LSTM model...
# (Include your model building and training here)

# Make predictions
predictions = model.predict(X_test)

# Inverse transform the predictions and actual values
predictions = target_scaler.inverse_transform(predictions)
y_test_inverse = target_scaler.inverse_transform(y_test.reshape(-1, 1))

# Plotting the results
plt.figure(figsize=(14, 7))
plt.plot(data['Date'].iloc[train_size + time_step:], y_test_inverse, label='Actual Price', color='blue')
plt.plot(data['Date'].iloc[train_size + time_step:], predictions, label='Predicted Price', color='orange')
plt.title('Nifty 50 Price Prediction with LSTM')
plt.xlabel('Date')
plt.ylabel('Price')
plt.xticks(rotation=45)
plt.legend()
plt.show()
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step

# %%
print("Scaled Features Sample:\n", features_scaled[:5])
print("Scaled Target Sample:\n", target_scaled[:5])
# Out:
# Scaled Features Sample:
#  [[0.50400669 0.18530327 0.13019321 0.0895483  0.05520522 0.0390347
#   0.17537634 0.13952276 0.09733801 0.06823647 0.04788514]
#  [0.44568808 0.18524299 0.13165909 0.09107011 0.05595654 0.03961217
#   0.17454833 0.14028334 0.09834954 0.06916503 0.04870741]
#  [0.45003516 0.18620456 0.1335734  0.0926968  0.05681247 0.0402464
#   0.17534142 0.14167487 0.09969063 0.07032292 0.04970785]
#  [0.41619877 0.18652801 0.13539972 0.09413386 0.05769101 0.04085033
#   0.17560108 0.14281563 0.10090136 0.07139374 0.050643  ]
#  [0.45287325 0.18700321 0.13723755 0.0955931  0.05858959 0.04149927
#   0.17634944 0.14413164 0.10220451 0.07253081 0.05163088]]
# Scaled Target Sample:
#  [[0.19192242]
#  [0.18607329]
#  [0.20152439]
#  [0.19693691]
#  [0.20208081]]

# %%
print(data.isnull().sum())
print(data.describe())
# Out:
# Date       0
# Open       0
# High       0
# Low        0
# Close      0
# Volume     0
# SMA_20     0
# EMA_20     0
# SMA_50     0
# EMA_50     0
# SMA_100    0
# EMA_100    0
# SMA_150    0
# EMA_150    0
# SMA_200    0
# EMA_200    0
# RSI        0
# dtype: int64
#                Open          High           Low         Close        Volume  \
# count   2244.000000   2244.000000   2244.000000   2244.000000  2.244000e+03
# mean    7977.086481   8015.160279   7925.743867   7970.507646  1.748864e+05
# std     2177.369757   2180.045632   2169.493435   2174.818838  1.600179e+05
# min     4623.149902   4623.149902   4531.149902   4544.200195  0.000000e+00
# 25%     5883.875122   5911.750000   5839.937622   5879.200073  0.000000e+00
# 50%     7994.924805   8036.399902   7940.424805   7979.500000  1.610500e+05
# 75%     9988.437744  10026.462402   9952.125244   9985.787354  2.245500e+05
# max    12274.900391  12293.900391  12252.750000  12271.799805  1.414800e+06
#
# ...

# %%
print("Predictions Sample:\n", predictions[:5])
print("Actual Prices Sample:\n", y_test_inverse[:5])
# Out:
# Predictions Sample:
#  [[63462408.]
#  [63462408.]
#  [63462400.]
#  [63462400.]
#  [63462400.]]
# Actual Prices Sample:
#  [[10360.15039062]
#  [10195.15039062]
#  [10094.25      ]
#  [10124.34960938]
#  [10155.25      ]]

# %%
# Plotting the results
plt.figure(figsize=(14, 7))
plt.plot(data['Date'].iloc[train_size + time_step:], y_test_inverse, label='Actual Price', color='blue')
plt.plot(data['Date'].iloc[train_size + time_step:], predictions, label='Predicted Price', color='orange')
plt.title('Nifty 50 Price Prediction with LSTM')
plt.xlabel('Date')
plt.ylabel('Price')
plt.xticks(rotation=45)
plt.legend()
plt.show()

# %% [markdown]
# # **WITH MA ONLY**

# %%
import pandas as pd
import numpy as np

# Load your dataset
data = pd.read_csv('/content/NSE501.csv')
data['Date'] = pd.to_datetime(data['Date'])

# Calculate moving averages
windows = [20, 50, 100, 150, 200]  # Define moving average windows
for window in windows:
    data[f'SMA_{window}'] = data['Close'].rolling(window=window).mean()

# Drop rows with NaN values
data = data.dropna()

# Select features and target
features = data[[f'SMA_{window}' for window in windows]]
target = data['Close']

# %%
from sklearn.preprocessing import MinMaxScaler

# Initialize scalers
feature_scaler = MinMaxScaler()
target_scaler = MinMaxScaler()

# Normalize features
features_scaled = feature_scaler.fit_transform(features)

# Reshape target for scaling
target_scaled = target.values.reshape(-1, 1)
target_scaled = target_scaler.fit_transform(target_scaled)

# %%
# Create the datasets
time_step = 10  # Number of previous time steps to consider
X, y = [], []
for i in range(time_step, len(features_scaled)):
    X.append(features_scaled[i-time_step:i])
    y.append(target_scaled[i])

X, y = np.array(X), np.array(y)

# Split into training and testing sets
train_size = int(len(X) * 0.8)
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout

# Build the LSTM model
model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(Dropout(0.2))
model.add(LSTM(50, return_sequences=False))
model.add(Dropout(0.2))
model.add(Dense(1))  # Output layer for prediction

# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
# Train the model
model.fit(X_train, y_train, epochs=50, batch_size=32)
# Out:
# Epoch 1/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - loss: 0.0531
# Epoch 2/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 0.0046
# Epoch 3/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.0035
# Epoch 4/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0026
# Epoch 5/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0025
# Epoch 6/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0026
# Epoch 7/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0023
# Epoch 8/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0024
# Epoch 9/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0024
# Epoch 10/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0023
# Epoch 11/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0021
# Epoch 12/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0020
# Epoch 13/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0019
# Epoch 14/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0019
# Epoch 15/50
# ...

# %%
# Make predictions
predictions = model.predict(X_test)

# Inverse transform the predictions and actual values using target_scaler
predictions = target_scaler.inverse_transform(predictions)
y_test_inverse = target_scaler.inverse_transform(y_test.reshape(-1, 1))

# Plotting the results
import matplotlib.pyplot as plt

plt.figure(figsize=(14, 7))
plt.plot(data['Date'].iloc[train_size + time_step:], y_test_inverse, label='Actual Price', color='blue')
plt.plot(data['Date'].iloc[train_size + time_step:], predictions, label='Predicted Price', color='orange')
plt.title('Nifty 50 Price Prediction with LSTM Using Moving Averages')
plt.xlabel('Date')
plt.ylabel('Price')
plt.xticks(rotation=45)
plt.legend()
plt.show()
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step

# %% [markdown]
# # **Using the rsi now**

# %%
import pandas as pd
import numpy as np

# Load your dataset
data = pd.read_csv('/content/NSE502.csv')
data['Date'] = pd.to_datetime(data['Date'])

# Calculate the RSI
def calculate_rsi(data, window=14):
    delta = data['Close'].diff()
    gain = (delta.where(delta > 0, 0)).rolling(window=window).mean()
    loss = (-delta.where(delta < 0, 0)).rolling(window=window).mean()
    rs = gain / loss
    rsi = 100 - (100 / (1 + rs))
    return rsi

# Apply the RSI calculation
data['RSI'] = calculate_rsi(data)

# Drop rows with NaN values
data = data.dropna()

# Select features and target
features = data[['RSI']]
target = data['Close']

# %%
from sklearn.preprocessing import MinMaxScaler

# Initialize scalers
feature_scaler = MinMaxScaler()
target_scaler = MinMaxScaler()

# Normalize features
features_scaled = feature_scaler.fit_transform(features)

# Reshape target for scaling
target_scaled = target.values.reshape(-1, 1)
target_scaled = target_scaler.fit_transform(target_scaled)

# %%
# Create the datasets
time_step = 10  # Number of previous time steps to consider
X, y = [], []
for i in range(time_step, len(features_scaled)):
    X.append(features_scaled[i-time_step:i])
    y.append(target_scaled[i])

X, y = np.array(X), np.array(y)

# Split into training and testing sets
train_size = int(len(X) * 0.8)
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout

# Build the LSTM model
model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(Dropout(0.2))
model.add(LSTM(50, return_sequences=False))
model.add(Dropout(0.2))
model.add(Dense(1))  # Output layer for prediction

# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
# Train the model
model.fit(X_train, y_train, epochs=50, batch_size=32)
# Out:
# Epoch 1/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - loss: 0.0646
# Epoch 2/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0442
# Epoch 3/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 0.0408
# Epoch 4/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0430
# Epoch 5/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0432
# Epoch 6/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0419
# Epoch 7/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0422
# Epoch 8/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0433
# Epoch 9/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0422
# Epoch 10/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0432
# Epoch 11/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0436
# Epoch 12/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0435
# Epoch 13/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0402
# Epoch 14/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0426
# Epoch 15/50
# ...

# %%
# Make predictions
predictions = model.predict(X_test)

# Inverse transform the predictions and actual values using target_scaler
predictions = target_scaler.inverse_transform(predictions)
y_test_inverse = target_scaler.inverse_transform(y_test.reshape(-1, 1))

# Plotting the results
import matplotlib.pyplot as plt

plt.figure(figsize=(14, 7))
plt.plot(data['Date'].iloc[train_size + time_step:], y_test_inverse, label='Actual Price', color='blue')
plt.plot(data['Date'].iloc[train_size + time_step:], predictions, label='Predicted Price', color='orange')
plt.title('Nifty 50 Price Prediction with LSTM Using RSI')
plt.xlabel('Date')
plt.ylabel('Price')
plt.xticks(rotation=45)
plt.legend()
plt.show()
# Out:
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step

# %% [markdown]
# # RNN

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN, Dense, Dropout

# Build the RNN model
rnn_model = Sequential()
rnn_model.add(SimpleRNN(50, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])))
rnn_model.add(Dropout(0.2))
rnn_model.add(SimpleRNN(50, return_sequences=False))
rnn_model.add(Dropout(0.2))
rnn_model.add(Dense(1))  # Output layer for prediction

# Compile the model
rnn_model.compile(optimizer='adam', loss='mean_squared_error')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
# Train the RNN model
rnn_model.fit(X_train, y_train, epochs=50, batch_size=32)
# Out:
# Epoch 1/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.1693
# Epoch 2/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0649
# Epoch 3/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0572
# Epoch 4/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0535
# Epoch 5/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0511
# Epoch 6/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0478
# Epoch 7/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0499
# Epoch 8/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0460
# Epoch 9/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0460
# Epoch 10/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0449
# Epoch 11/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0445
# Epoch 12/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0444
# Epoch 13/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0434
# Epoch 14/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0458
# Epoch 15/50
# ...

# %%
  # Make predictions
rnn_predictions = rnn_model.predict(X_test)

# Inverse transform the predictions and actual values using target_scaler
rnn_predictions = target_scaler.inverse_transform(rnn_predictions)
y_test_inverse = target_scaler.inverse_transform(y_test.reshape(-1, 1))

# Plotting the results
plt.figure(figsize=(14, 7))
plt.plot(data['Date'].iloc[train_size + time_step:], y_test_inverse, label='Actual Price', color='blue')
plt.plot(data['Date'].iloc[train_size + time_step:], rnn_predictions, label='Predicted Price', color='orange')
plt.title('Nifty 50 Price Prediction with RNN Using RSI')
plt.xlabel('Date')
plt.ylabel('Price')
plt.xticks(rotation=45)
plt.legend()
plt.show()
# Out:
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step

# %%
import pandas as pd

# Load your dataset
data = pd.read_csv('/content/NSE501.csv')
data['Date'] = pd.to_datetime(data['Date'])

# Calculate moving averages
data['MA20'] = data['Close'].rolling(window=20).mean()
data['MA50'] = data['Close'].rolling(window=50).mean()
data['MA100'] = data['Close'].rolling(window=100).mean()
data['MA150'] = data['Close'].rolling(window=150).mean()
data['MA200'] = data['Close'].rolling(window=200).mean()

# Drop rows with NaN values
data = data.dropna()

# Select features and target
features = data[['MA20', 'MA50', 'MA100', 'MA150', 'MA200']]
target = data['Close']

# %%
from sklearn.preprocessing import MinMaxScaler

# Initialize scalers
feature_scaler = MinMaxScaler()
target_scaler = MinMaxScaler()

# Normalize features
features_scaled = feature_scaler.fit_transform(features)

# Reshape target for scaling
target_scaled = target.values.reshape(-1, 1)
target_scaled = target_scaler.fit_transform(target_scaled)

# %%
import numpy as np

# Create the datasets
time_step = 10  # Number of previous time steps to consider
X, y = [], []
for i in range(time_step, len(features_scaled)):
    X.append(features_scaled[i-time_step:i])
    y.append(target_scaled[i])

X, y = np.array(X), np.array(y)

# Split into training and testing sets
train_size = int(len(X) * 0.8)
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN, Dense, Dropout

# Build the RNN model
rnn_model = Sequential()
rnn_model.add(SimpleRNN(50, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])))
rnn_model.add(Dropout(0.2))
rnn_model.add(SimpleRNN(50, return_sequences=False))
rnn_model.add(Dropout(0.2))
rnn_model.add(Dense(1))  # Output layer for prediction

# Compile the model
rnn_model.compile(optimizer='adam', loss='mean_squared_error')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
# Train the RNN model
rnn_model.fit(X_train, y_train, epochs=50, batch_size=32)
# Out:
# Epoch 1/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.2203
# Epoch 2/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0548
# Epoch 3/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0348
# Epoch 4/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0243
# Epoch 5/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0200
# Epoch 6/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0151
# Epoch 7/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0131
# Epoch 8/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0104
# Epoch 9/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0086
# Epoch 10/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0080
# Epoch 11/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0075
# Epoch 12/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0079
# Epoch 13/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0073
# Epoch 14/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0056
# Epoch 15/50
# ...

# %%
# Make predictions
rnn_predictions = rnn_model.predict(X_test)

# Inverse transform the predictions and actual values using target_scaler
rnn_predictions = target_scaler.inverse_transform(rnn_predictions)
y_test_inverse = target_scaler.inverse_transform(y_test.reshape(-1, 1))

# Plotting the results
import matplotlib.pyplot as plt

plt.figure(figsize=(14, 7))
plt.plot(data['Date'].iloc[train_size + time_step:], y_test_inverse, label='Actual Price', color='blue')
plt.plot(data['Date'].iloc[train_size + time_step:], rnn_predictions, label='Predicted Price', color='orange')
plt.title('Nifty 50 Price Prediction with RNN Using Moving Averages')
plt.xlabel('Date')
plt.ylabel('Price')
plt.xticks(rotation=45)
plt.legend()
plt.show()
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step

# %% [markdown]
# **************

# %%
from sklearn.metrics import mean_squared_error

mse = mean_squared_error(y_test_inverse, rnn_predictions)
print(f'Mean Squared Error: {mse}')
# Out:
# Mean Squared Error: 71817.70185390678

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping

# Load your dataset
data = pd.read_csv('/content/NSE501.csv')
data['Date'] = pd.to_datetime(data['Date'])

# Calculate moving averages
data['MA20'] = data['Close'].rolling(window=20).mean()
data['MA50'] = data['Close'].rolling(window=50).mean()
data['MA100'] = data['Close'].rolling(window=100).mean()
data['MA150'] = data['Close'].rolling(window=150).mean()
data['MA200'] = data['Close'].rolling(window=200).mean()

# Drop rows with NaN values
data = data.dropna()

# Select features and target
features = data[['MA20', 'MA50', 'MA100', 'MA150', 'MA200']]
target = data['Close']

# Normalize features and target
feature_scaler = MinMaxScaler()
target_scaler = MinMaxScaler()

features_scaled = feature_scaler.fit_transform(features)
target_scaled = target.values.reshape(-1, 1)
target_scaled = target_scaler.fit_transform(target_scaled)

# Create datasets for RNN
time_step = 10
X, y = [], []
for i in range(time_step, len(features_scaled)):
    X.append(features_scaled[i-time_step:i])
    y.append(target_scaled[i])

X, y = np.array(X), np.array(y)

# Split into training and testing sets
train_size = int(len(X) * 0.8)
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

# Build the RNN model
rnn_model = Sequential()
rnn_model.add(SimpleRNN(50, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])))
rnn_model.add(Dropout(0.2))
rnn_model.add(SimpleRNN(50, return_sequences=False))
rnn_model.add(Dropout(0.2))
rnn_model.add(Dense(1))

# Compile the model
rnn_model.compile(optimizer='adam', loss='mean_squared_error')

# Train the model with early stopping
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
history = rnn_model.fit(X_train, y_train, epochs=50, batch_size=32, validation_split=0.1, callbacks=[early_stopping])

# Make predictions
rnn_predictions = rnn_model.predict(X_test)

# Inverse transform the predictions and actual values
rnn_predictions_inverse = target_scaler.inverse_transform(rnn_predictions)
y_test_inverse = target_scaler.inverse_transform(y_test.reshape(-1, 1))

# Evaluate model performance
mse = mean_squared_error(y_test_inverse, rnn_predictions_inverse)
print(f'Mean Squared Error for RNN: {mse}')

# Plotting the results
plt.figure(figsize=(14, 7))
plt.plot(data['Date'].iloc[train_size + time_step:], y_test_inverse, label='Actual Price', color='blue')
plt.plot(data['Date'].iloc[train_size + time_step:], rnn_predictions_inverse, label='Predicted Price', color='orange')
plt.title('Nifty 50 Price Prediction with RNN Using Moving Averages')
plt.xlabel('Date')
plt.ylabel('Price')
plt.xticks(rotation=45)
plt.legend()
plt.show()
# Out:
# Epoch 1/50
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step - loss: 0.2296 - val_loss: 0.0016
# Epoch 2/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0508 - val_loss: 0.0013
# Epoch 3/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0249 - val_loss: 0.0015
# Epoch 4/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0172 - val_loss: 0.0048
# Epoch 5/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0153 - val_loss: 9.3851e-04
# Epoch 6/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0116 - val_loss: 0.0065
# Epoch 7/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0096 - val_loss: 7.1539e-04
# Epoch 8/50
# ...

# %% [markdown]
# # *Hyperparameter Tuning*

# %%
# !pip install keras-tuner
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.1/129.1 kB 2.9 MB/s eta 0:00:00
# ...

# %%
# Install Keras Tuner
# !pip install keras-tuner

# %%
from kerastuner import RandomSearch

def build_model(hp):
    model = Sequential()
    model.add(SimpleRNN(hp.Int('units', min_value=50, max_value=100, step=10), return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])))
    model.add(Dropout(0.2))
    model.add(SimpleRNN(hp.Int('units', min_value=50, max_value=100, step=10), return_sequences=False))
    model.add(Dropout(0.2))
    model.add(Dense(1))

    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

tuner = RandomSearch(build_model, objective='val_loss', max_trials=5, executions_per_trial=1)

tuner.search(X_train, y_train, epochs=50, validation_split=0.1)
best_model = tuner.get_best_models(num_models=1)[0]
# Out:
# Trial 5 Complete [00h 00m 37s]
# val_loss: 0.0005120414425618947
#
# Best val_loss So Far: 0.0005120414425618947
# Total elapsed time: 00h 02m 57s
# /usr/local/lib/python3.10/dist-packages/keras/src/saving/saving_lib.py:576: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 18 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))

# %%
# Evaluate the best model
best_model.evaluate(X_test, y_test)

# Make predictions using the best model
best_rnn_predictions = best_model.predict(X_test)

# Inverse transform the predictions and actual values
best_rnn_predictions_inverse = target_scaler.inverse_transform(best_rnn_predictions)
y_test_inverse = target_scaler.inverse_transform(y_test.reshape(-1, 1))

# Calculate Mean Squared Error for the best model
best_mse = mean_squared_error(y_test_inverse, best_rnn_predictions_inverse)
print(f'Mean Squared Error for Tuned RNN: {best_mse}')

# Plotting the results
plt.figure(figsize=(14, 7))
plt.plot(data['Date'].iloc[train_size + time_step:], y_test_inverse, label='Actual Price', color='blue')
plt.plot(data['Date'].iloc[train_size + time_step:], best_rnn_predictions_inverse, label='Tuned RNN Predicted Price', color='orange')
plt.title('Nifty 50 Price Prediction with Tuned RNN')
plt.xlabel('Date')
plt.ylabel('Price')
plt.xticks(rotation=45)
plt.legend()
plt.show()
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.1010e-04
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step
# Mean Squared Error for Tuned RNN: 57304.245213602335

# %%
best_model.save('tuned_rnn_model.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %% [markdown]
# # *moving to more bigger things*

# %%
# Bollinger Bands
def bollinger_bands(data, window=20, num_sd=2):
    rolling_mean = data['Close'].rolling(window=window).mean()
    rolling_std = data['Close'].rolling(window=window).std()
    data['Upper Band'] = rolling_mean + (rolling_std * num_sd)
    data['Lower Band'] = rolling_mean - (rolling_std * num_sd)

# Lag Features
def create_lagged_features(data, lag=1):
    for i in range(1, lag + 1):
        data[f'Lag_{i}'] = data['Close'].shift(i)

# Apply Bollinger Bands
bollinger_bands(data)

# Create lag features (for example, 3 lags)
create_lagged_features(data, lag=3)

# %%
from keras.layers import Bidirectional

model = Sequential()
model.add(Bidirectional(SimpleRNN(50, return_sequences=True), input_shape=(X_train.shape[1], X_train.shape[2])))
# Add more layers and compile as before
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/bidirectional.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
from sklearn.metrics import mean_absolute_percentage_error

mape = mean_absolute_percentage_error(y_test_inverse, predictions)
print(f'MAPE: {mape}')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-108-549340cd3601> in <cell line: 3>()
#       1 from sklearn.metrics import mean_absolute_percentage_error
#       2
# ----> 3 mape = mean_absolute_percentage_error(y_test_inverse, predictions)
#       4 print(f'MAPE: {mape}')
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/_param_validation.py in wrapper(*args, **kwargs)
#     211                     )
#     212                 ):
# --> 213                     return func(*args, **kwargs)
#     214             except InvalidParameterError as e:
#     215                 # When the function is just a wrapper around an estimator, we allow
#
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py in mean_absolute_percentage_error(y_true, y_pred, sample_weight, multioutput)
#     397     np.float64(112589990684262.48)
#     398     """
# ...

# %%
print(f'Shape of y_test_inverse: {y_test_inverse.shape}')
print(f'Shape of predictions: {predictions.shape}')
# Out:
# Shape of y_test_inverse: (407, 1)
# Shape of predictions: (484, 1)

# %%
# Ensure y_test is reshaped correctly
y_test_inverse = y_test.reshape(-1, 1)  # Reshape if necessary

# Check shapes
print(f'Shape of y_test_inverse: {y_test_inverse.shape}')
print(f'Shape of predictions: {predictions.shape}')

# Ensure the lengths match
min_length = min(y_test_inverse.shape[0], predictions.shape[0])
y_test_inverse = y_test_inverse[:min_length]
predictions = predictions[:min_length]

# Now calculate MAPE
mape = mean_absolute_percentage_error(y_test_inverse, predictions)
print(f'MAPE: {mape}')
# Out:
# Shape of y_test_inverse: (407, 1)
# Shape of predictions: (484, 1)
# MAPE: 8209.932693745915

# %%
from sklearn.metrics import mean_absolute_percentage_error

mape = mean_absolute_percentage_error(y_test_inverse, predictions)
print(f'MAPE: {mape}')
# Out:
# MAPE: 8209.932693745915
